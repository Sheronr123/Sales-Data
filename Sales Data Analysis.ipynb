# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install pyarrow

# %%
sd = pd.read_feather(r'Sales_data.ftr')
sd
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
sd.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
sd = sd.dropna(how='all')

# %%
sd.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
sd[sd.duplicated()]
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# 1302      177795    Apple Airpods Headphones                 1         150
# 1684      178158        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 186563  Order ID                     Product  Quantity Ordered  Price Each
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
#
#             Order Date                        Purchase Address
# ...

# %%
sd = sd.drop_duplicates()

# %%
sd.duplicated().sum()
# Out:
# 0

# %%
sd['Order Date']
# Out:
# 0         04/19/19 08:46
# 2         04/07/19 22:30
# 3         04/12/19 14:38
# 4         04/12/19 14:38
# 5         04/30/19 09:27
#                ...
# 186845    09/17/19 20:56
# 186846    09/01/19 16:00
# 186847    09/23/19 07:39
# 186848    09/19/19 17:30
# 186849    09/30/19 00:18
# Name: Order Date, Length: 185687, dtype: object

# %%
sd['Order Date'][0].split()[0].split('/')[0]

sd['Order Month'] = sd['Order Date'].apply(lambda date: date.split()[0].split('/')[0])
sd
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Order Month
# ...

# %%
order_filter = sd['Order Month'] == 'Order'

# %%
sd = sd[~order_filter]

# %%
import warnings
from warnings import filterwarnings
filterwarning('ignore')
sd[order_filter]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 import warnings
#       2 from warnings import filterwarnings
# ----> 3 filterwarning('ignore')
#       4 sd[order_filter]
#
# NameError: name 'filterwarning' is not defined

# %%
sd['Order Month'] = sd['Order Month'].astype(int)
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_895/2654901094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['Order Month'] = sd['Order Month'].astype(int)

# %%
sd
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  Order Month
# ...

# %%
sd['Order Month'].dtype
# Out:
# dtype('int64')

# %%
sd['Quantity Ordered'] = sd['Quantity Ordered'].astype(int)
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_895/3550931738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['Quantity Ordered'] = sd['Quantity Ordered'].astype(int)

# %%
sd['Quantity Ordered'].dtype
# Out:
# dtype('int64')

# %%
sd['Price Each'] = sd['Price Each'].astype(float)
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_895/3716898448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['Price Each'] = sd['Price Each'].astype(float)

# %%
sd['Price Each'].dtype
# Out:
# dtype('float64')

# %%
sd.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Order Month           int64
# dtype: object

# %%
sd
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Order Month
# ...

# %%
sd['Sales'] = sd['Price Each'] * sd['Quantity Ordered'] 
sd
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_895/2115477566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['Sales'] = sd['Price Each'] * sd['Quantity Ordered']
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
sd_plot = sd.groupby(['Order Month'])['Sales'].sum()

# %%
sd_plot.plot(kind ='bar')
# Out:
# <Axes: xlabel='Order Month'>

# %%
sd = sd.reset_index()
sd
# Out:
#          index Order ID                     Product  Quantity Ordered  \
# 0            0   176558        USB-C Charging Cable                 2
# 1            2   176559  Bose SoundSport Headphones                 1
# 2            3   176560                Google Phone                 1
# 3            4   176560            Wired Headphones                 1
# 4            5   176561            Wired Headphones                 1
# ...        ...      ...                         ...               ...
# 185681  186845   259353      AAA Batteries (4-pack)                 3
# 185682  186846   259354                      iPhone                 1
# 185683  186847   259355                      iPhone                 1
# 185684  186848   259356      34in Ultrawide Monitor                 1
# 185685  186849   259357        USB-C Charging Cable                 1
#
#         Price Each      Order Date                         Purchase Address  \
# ...

# %%
sd['Purchase Address'][0].split(',')[1]
# Out:
# ' Dallas'

# %%
def city_max(address):
    return address.split(',')[1]

sd['Purchase City'] = sd['Purchase Address'].apply(city_max)

# %%
sd_city_plot = sd['Purchase City'].value_counts()

# %%
sd_city_plot.plot(kind = 'pie', autopct = '%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sd_products = sd['Product'].unique()

# %%
countdf = sd.groupby(['Product']).agg({'Quantity Ordered':'sum', 'Price Each':'mean'})
countdf = countdf.reset_index()
countdf
# Out:
#                        Product  Quantity Ordered  Price Each
# 0                 20in Monitor              4126      109.99
# 1       27in 4K Gaming Monitor              6239      389.99
# 2             27in FHD Monitor              7541      149.99
# 3       34in Ultrawide Monitor              6192      379.99
# 4        AA Batteries (4-pack)             27615        3.84
# 5       AAA Batteries (4-pack)             30986        2.99
# 6     Apple Airpods Headphones             15637      150.00
# 7   Bose SoundSport Headphones             13430       99.99
# 8                Flatscreen TV              4813      300.00
# 9                 Google Phone              5529      600.00
# 10                    LG Dryer               646      600.00
# 11          LG Washing Machine               666      600.00
# 12    Lightning Charging Cable             23169       14.95
# 13          Macbook Pro Laptop              4725     1700.00
# ...

# %%
total_products = countdf['Product'].unique()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar(countdf['Product'], countdf['Quantity Ordered'], color = 'g')
ax2.plot(countdf['Product'], countdf['Price Each'])
ax1.set_xticklabels(total_products, rotation = 'vertical', fontsize = 12)
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_895/3938950688.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(total_products, rotation = 'vertical', fontsize = 12)
# [Text(0, 0, '20in Monitor'),
#  Text(1, 0, '27in 4K Gaming Monitor'),
#  Text(2, 0, '27in FHD Monitor'),
#  Text(3, 0, '34in Ultrawide Monitor'),
#  Text(4, 0, 'AA Batteries (4-pack)'),
#  Text(5, 0, 'AAA Batteries (4-pack)'),
#  Text(6, 0, 'Apple Airpods Headphones'),
#  Text(7, 0, 'Bose SoundSport Headphones'),
#  Text(8, 0, 'Flatscreen TV'),
#  Text(9, 0, 'Google Phone'),
#  Text(10, 0, 'LG Dryer'),
#  Text(11, 0, 'LG Washing Machine'),
#  Text(12, 0, 'Lightning Charging Cable'),
#  Text(13, 0, 'Macbook Pro Laptop'),
#  Text(14, 0, 'ThinkPad Laptop'),
#  Text(15, 0, 'USB-C Charging Cable'),
#  Text(16, 0, 'Vareebadd Phone'),
#  Text(17, 0, 'Wired Headphones'),
#  Text(18, 0, 'iPhone')]

# %%
sd
# Out:
#          index Order ID                     Product  Quantity Ordered  \
# 0            0   176558        USB-C Charging Cable                 2
# 1            2   176559  Bose SoundSport Headphones                 1
# 2            3   176560                Google Phone                 1
# 3            4   176560            Wired Headphones                 1
# 4            5   176561            Wired Headphones                 1
# ...        ...      ...                         ...               ...
# 185681  186845   259353      AAA Batteries (4-pack)                 3
# 185682  186846   259354                      iPhone                 1
# 185683  186847   259355                      iPhone                 1
# 185684  186848   259356      34in Ultrawide Monitor                 1
# 185685  186849   259357        USB-C Charging Cable                 1
#
#         Price Each      Order Date                         Purchase Address  \
# ...

# %%
top_five = sd['Product'].value_counts().head().index
top_five
# Out:
# Index(['USB-C Charging Cable', 'Lightning Charging Cable',
#        'AAA Batteries (4-pack)', 'AA Batteries (4-pack)', 'Wired Headphones'],
#       dtype='object', name='Product')

# %%
sd['Product'].isin(top_five)
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 185681     True
# 185682    False
# 185683    False
# 185684    False
# 185685     True
# Name: Product, Length: 185686, dtype: bool

# %%
top_five_df = pd.Dataframe(sd[sd['Product'].isin(top_five)])

# %%
top_five_df
# Out:
#          index Order ID                 Product  Quantity Ordered  Price Each  \
# 0            0   176558    USB-C Charging Cable                 2       11.95
# 3            4   176560        Wired Headphones                 1       11.99
# 4            5   176561        Wired Headphones                 1       11.99
# 5            6   176562    USB-C Charging Cable                 1       11.95
# 7            8   176564    USB-C Charging Cable                 1       11.95
# ...        ...      ...                     ...               ...         ...
# 185676  186840   259349  AAA Batteries (4-pack)                 1        2.99
# 185678  186842   259350    USB-C Charging Cable                 1       11.95
# 185680  186844   259352    USB-C Charging Cable                 1       11.95
# 185681  186845   259353  AAA Batteries (4-pack)                 3        2.99
# 185685  186849   259357    USB-C Charging Cable                 1       11.95
#
# ...

# %%
monthly_highest_product = top_five_df.groupby(['Order Month','Product'])
pivot monthly_highest_product.unstack()
monthly_highest_product

# %%
pivot.plot(figsize = (8,6))
# Out:
# <Axes: xlabel='Order Month'>

# %%
sd['Order ID'].duplicated(keep = False)
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 185681    False
# 185682    False
# 185683    False
# 185684    False
# 185685    False
# Name: Order ID, Length: 185686, dtype: bool

# %%
sd_duplicates = sd[sd['Order ID'].duplicated(keep = False)]
sd_duplicates
# Out:
#          index Order ID                 Product  Quantity Ordered  Price Each  \
# 2            3   176560            Google Phone                 1      600.00
# 3            4   176560        Wired Headphones                 1       11.99
# 17          18   176574            Google Phone                 1      600.00
# 18          19   176574    USB-C Charging Cable                 1       11.95
# 30          32   176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...      ...                     ...               ...         ...
# 185629  186792   259303   AA Batteries (4-pack)                 1        3.84
# 185640  186803   259314        Wired Headphones                 1       11.99
# 185641  186804   259314  AAA Batteries (4-pack)                 2        2.99
# 185677  186841   259350            Google Phone                 1      600.00
# 185678  186842   259350    USB-C Charging Cable                 1       11.95
#
# ...

# %%
sd_grouped = sd_duplicates.groupby(['Order ID'])['Product'].apply(lambda x:','.join(x)).reset_index().rename(columns = {'Product':'Grouped Product'})

# %%
grouped_total_data = sd_duplicates.merge(sd_grouped, how='left', on='Order ID')

# %%
finaldata = grouped_total_data.drop_duplicates(subset='Order ID')

# %%
finaldata
# Out:
#         index Order ID                   Product  Quantity Ordered  \
# 0           3   176560              Google Phone                 1
# 2          18   176574              Google Phone                 1
# 4          32   176586    AAA Batteries (4-pack)                 2
# 6         119   176672  Lightning Charging Cable                 1
# 8         129   176681  Apple Airpods Headphones                 1
# ...       ...      ...                       ...               ...
# 14118  186761   259277                    iPhone                 1
# 14120  186783   259297                    iPhone                 1
# 14122  186791   259303    34in Ultrawide Monitor                 1
# 14124  186803   259314          Wired Headphones                 1
# 14126  186841   259350              Google Phone                 1
#
#        Price Each      Order Date                        Purchase Address  \
# 0          600.00  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# ...

# %%
finaldata['Grouped Product'].head().value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
